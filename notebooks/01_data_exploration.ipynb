# %% [markdown]
# # FIFA 2026 — Data Exploration
#
# Run after `python scripts/download_data.py` and `python scripts/build_features.py`.

# %%
import pandas as pd
from pathlib import Path

ROOT = Path('..').resolve()
features = pd.read_parquet(ROOT / 'data/processed/features.parquet')
print(f'Rows: {len(features):,}')
features.head()

# %%
features['result'].value_counts(normalize=True)

# %%
features.isna().mean().sort_values(ascending=False).head(15)
